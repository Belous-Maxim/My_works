# %%
import requests
import time
from bs4 import BeautifulSoup as BS
import pandas as pd

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from fake_useragent import UserAgent
UserAgent().chrome
# Out:
# 'Mozilla/5.0 (X11; OpenBSD i386) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36'

# %%
hrefs = ['https://online.metro-cc.ru/category/myasnye/indeyka',
 'https://online.metro-cc.ru/category/myasnaya-gastronomiya/kopchenye-kolbasy',
 'https://online.metro-cc.ru/category/elektronika-tekhnika/krasota-zdorove',
 'https://online.metro-cc.ru/category/ovoshchi-i-frukty/zamorozhennye-ovoshchi',
 'https://online.metro-cc.ru/category/professionalnoe-oborudovanie/oborudovanie-dlya-uborki',
 'https://online.metro-cc.ru/category/elektronika-tekhnika/klimaticheskaya-tekhnika',
 'https://online.metro-cc.ru/category/alkogolnaya-produkciya/posuda-i-aksessuary-dlya-napitkov',
 'https://msk.metro-cc.ru/category/moloko-yajca/moloko',
 'https://online.metro-cc.ru/category/alkogolnaya-produkciya/likery',
 'https://msk.metro-cc.ru/category/moloko-yajca/jogurty-deserty',
 'https://msk.metro-cc.ru/category/moloko-yajca/slivki',
 'https://msk.metro-cc.ru/category/moloko-yajca/yajca',
 'https://online.metro-cc.ru/category/myasnaya-gastronomiya/sosiski-sardelki',
 'https://online.metro-cc.ru/category/alkogolnaya-produkciya/tekila',
 'https://online.metro-cc.ru/category/tovary-dlja-zhivotnyh/korma-dlya-ptits',
 'https://online.metro-cc.ru/category/myasnaya-gastronomiya/delikatesy',
 'https://msk.metro-cc.ru/category/ofis-obuchenie-hobbi/tovary-dlya-shkoly',
 'https://msk.metro-cc.ru/category/ofis-obuchenie-hobbi/pismennye-prinadlezhnosti',
 'https://online.metro-cc.ru/category/avtotovary/sredstva-bezopasnosti',
 'https://online.metro-cc.ru/category/vse-dlya-remonta/santekhnika',
 'https://online.metro-cc.ru/category/bakaleya/muka-vse-dlya-vypechki',
 'https://online.metro-cc.ru/category/rybnye/ikra',
 'https://msk.metro-cc.ru/category/ofis-obuchenie-hobbi/bumazhnaya-produkciya',
 'https://online.metro-cc.ru/category/alkogolnaya-produkciya/viski',
 'https://online.metro-cc.ru/category/bytovaya-himiya/osvezhiteli-vozduha',
 'https://online.metro-cc.ru/category/hleb-vypechka-konditerskie-izdeliya/shokolad-batonchiki',
 'https://online.metro-cc.ru/category/gotovye-bljuda-polufabrikaty/salati',
 'https://online.metro-cc.ru/category/rybnye/solenye',
 'https://online.metro-cc.ru/category/rybnye/preservy-pashtety',
 'https://online.metro-cc.ru/category/tovary-dlja-zhivotnyh/korma-konservy-dlja-koshek',
 'https://online.metro-cc.ru/category/professionalnoe-oborudovanie/posuda-dlya-obshchepita',
 'https://online.metro-cc.ru/category/chaj-kofe-kakao/cikorij-kofezameniteli',
 'https://online.metro-cc.ru/category/antibakterialnaya-produkciya/binty-povyazki',
 'https://msk.metro-cc.ru/category/ofis-obuchenie-hobbi/tovary-dlya-ofisa',
 'https://online.metro-cc.ru/category/syr-maslo/tvorozhnye-slivochnye-syry',
 'https://online.metro-cc.ru/category/zdorovoe-pitanie/hlebcy-113002',
 'https://online.metro-cc.ru/category/vse-dlya-remonta/stroitelnye-materialy',
 'https://online.metro-cc.ru/category/myasnye/govyadina',
 'https://online.metro-cc.ru/category/tovary-dlja-zhivotnyh/lakomstva-dlya-zhivotnyh',
 'https://online.metro-cc.ru/category/bytovaya-himiya/sredstva-dlya-mytya-posudy',
 'https://online.metro-cc.ru/category/chaj-kofe-kakao/kakao-kofejnye-napitki',
 'https://msk.metro-cc.ru/category/moloko-yajca/rastitelnoe-moloko',
 'https://msk.metro-cc.ru/category/ofis-obuchenie-hobbi/tovary-dlya-tvorchestva',
 'https://online.metro-cc.ru/category/myasnye/shashlyk-barbekyu',
 'https://online.metro-cc.ru/category/hleb-vypechka-konditerskie-izdeliya/konfety-podarochnye-nabory',
 'https://online.metro-cc.ru/category/myasnaya-gastronomiya/varenaya-kolbasa-vetchina',
 'https://online.metro-cc.ru/category/bezalkogolnye-napitki/pityevaya-voda-kulery',
 'https://online.metro-cc.ru/category/ovoshchi-i-frukty/svezhie-yagody',
 'https://online.metro-cc.ru/category/rybnye/polufabrikaty-103004',
 'https://online.metro-cc.ru/category/hleb-vypechka-konditerskie-izdeliya/hleb-lavash',
 'https://online.metro-cc.ru/category/rybnye/moreprodukty',
 'https://online.metro-cc.ru/category/detskie-tovary/igry-igrushki',
 'https://online.metro-cc.ru/category/tovary-dlja-zhivotnyh/igrushki-dlya-zhivotnyh',
 'https://msk.metro-cc.ru/category/moloko-yajca/tvorog',
 'https://online.metro-cc.ru/category/syr-maslo/polutverdye-syry',
 'https://online.metro-cc.ru/category/bakaleya/myasnye-konservy',
 'https://online.metro-cc.ru/category/kosmetika/tovary-dlya-muzhchin',
 'https://online.metro-cc.ru/category/tovary-dlja-zhivotnyh/korma-konservy-dlya-sobak',
 'https://online.metro-cc.ru/category/bezalkogolnye-napitki/napitki-105003',
 'https://msk.metro-cc.ru/category/moloko-yajca/syrki-glazirovannye-tvorozhnaya-massa',
 'https://online.metro-cc.ru/category/chaj-kofe-kakao/chay',
 'https://online.metro-cc.ru/category/gotovye-bljuda-polufabrikaty/blinchiki',
 'https://online.metro-cc.ru/category/avtotovary/avtokosmetika-aksessuary',
 'https://online.metro-cc.ru/category/detskie-tovary/podguzniki-trusiki-pelenki',
 'https://online.metro-cc.ru/category/bakaleya/siropy-toppingi',
 'https://online.metro-cc.ru/category/alkogolnaya-produkciya/shampanskoe-igristye-vina',
 'https://online.metro-cc.ru/category/professionalnoe-oborudovanie/krupnoe-professionalnoe-oborudovanie',
 'https://online.metro-cc.ru/category/bakaleya/krupy-bobovye']
new_hrefs = []
for i in hrefs:
    for m in range(1, 15):
        newurl = i + '?page={}'.format(m)
        
        new_hrefs.append(newurl)

# %%
all_pages = []

# %%
for i in new_hrefs:
    url_of_good = i
    page = requests.get(url_of_good, headers={'User-Agent': UserAgent().chrome})
    soup = BS(page.content, 'html.parser')
    name = soup.find('div', {'class': 'catalog-list'}).findAll('a', {'class': 'catalog-item_name'})
    for i in name:
        last_page = (i.get('href'))
        
        all_pages.append(last_page)

    time.sleep(1)

# %%
#добавляем http:
Last_urls = []
for number in all_pages:
    number = 'https://msk.metro-cc.ru' + number
    Last_urls.append(number)

# %%
with open("fileurls.txt", 'r') as f:
    score = [line.rstrip('\n') for line in f]

# %%
data_msk = []
m = 2000
for i in score:
    print(i)
    
    
    url = i
    page = requests.get(url, headers={'User-Agent': UserAgent().chrome})
    print(page)
    soup = BS(page.content, 'html.parser')
    name = soup.find('div', {'class': 'product-page__tablet-title'})
    if name is not None:
        name = name.text
        price = soup.find('p', {'class': 'price-card__new-price'})
        if price is not None:
            price = price.text
            price = price.split()
            price = ''.join(price)
        if price is None:
            price = soup.find('div', {'class': 'price-card__no-title'}).text
    
        
        article = soup.find('div', {'class': 'product-page__tablet-code'}).find('span')
        if article is not None:
            article = article.text
        photo = soup.find('div', {'class': 'product-page__content'}).find('div', {'class': 'product-page__slideshow'}).find('div', {'class': 'thumb product-page__zoom-img'})
        photo = str(photo)
        str1 = 'url('.join(photo.split('url(')[1:])
        photo = ');"><'.join(str1.split(');"><')[:-1])
    if name is None:
        article = None
        photo = None
    df_msk = pd.DataFrame(data_msk)
    
 
        
    

    
    data_msk.append({'Наименование': name, 'цена': price, 'Артикул': article, 'Ссылка на товар': url, 'Фотография': photo})
    time.sleep(1)

# %%
df1 = pd.read_excel('частьданны.xlsx')
df2 = pd.read_excel('частьданных9000-18000.xlsx')
df3 = pd.read_excel('частьданных13100-18000.xlsx')
df4 = pd.read_excel('частьданных16671-18000.xlsx')
df5 = pd.read_excel('Metro1.xlsx')

# %%
df6 = pd.DataFrame(data)

# %%
Big_df = pd.concat([df1, df2, df3, df4, df5, df6], ignore_index=True)

# %%
Big_df['Ссылка на товар'][2]
# Out:
# 'https://msk.metro-cc.ru/category/elektronika-tekhnika/televizory-audio-i-video/videooborudovanie/t22fte1280-thomson'

# %%
Big_df = Big_df.drop(Big_df.columns[0], 1)

# %%
Big_df
# Out:
#                                             Наименование           цена  \
# 0      Пакеты вакуумные GEMLUX два рулона в упаковке,...        999₽/уп
# 1      Мороженое протеиновое ICECRO Горький шоколад в...  Нет в наличии
# 2                           Телевизор T22FTE1280 THOMSON  Нет в наличии
# 3      Гренки ДОБРЫНОВ Палочки с прованскими травами,...      91.91₽/шт
# 4                     Сок RIOBA томатный с солью, 0,25 л      49.99₽/шт
# ...                                                  ...            ...
# 22827          Шоколад КІТКАТ Senses Delux Coconut, 112г      79.90₽/шт
# 22828  Сардина MONOLITH натуральная с добавлением мас...  Нет в наличии
# 22829                Тетрадь ESSELTE клетка А4 70 листов        159₽/шт
# 22830             Вдохновение Шоколад классический, 100г        125₽/уп
# 22831  Fellowes Пружины для переплета пластиковые бел...        149₽/шт
#
#       Артикул                                    Ссылка на товар  \
# ...

# %%
Big_df.nunique()
# Out:
# Наименование       20508
# цена                2687
# Артикул            22274
# Ссылка на товар    21727
# Фотография         21449
# dtype: int64

# %%
Big_df.to_excel('Metro_products.xlsx')

# %%
Big_df
# Out:
#        Unnamed: 0                                       Наименование  \
# 0               0  Пакеты вакуумные GEMLUX два рулона в упаковке,...
# 1               1  Мороженое протеиновое ICECRO Горький шоколад в...
# 2               2                       Телевизор T22FTE1280 THOMSON
# 3               3  Гренки ДОБРЫНОВ Палочки с прованскими травами,...
# 4               4                 Сок RIOBA томатный с солью, 0,25 л
# ...           ...                                                ...
# 20999        2462  Пленка для ламинирования SIGMA глянцевая 60x95...
# 21000        2463     Батончик FAZER Kismet шоколадно-вафельный, 55г
# 21001        2464      Esselte Папка-регистратор Rainbow 75мм желтая
# 21002        2465                      Хлебцы с семенами тыквы, 250г
# 21003        2466  Взбитый крем HULALA растворимый 24% с сахаром,...
#
#                 цена   Артикул  \
# 0            999₽/уп  627457.0
# 1      Нет в наличии  606118.0
# 2      Нет в наличии   95955.0
# ...
